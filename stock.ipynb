# %%
import sys
from pyqtwindow import Ui_MainWindow
from PyQt5.QtCore import pyqtSlot
from PyQt5.QtWidgets import QMainWindow, QApplication,QTableWidgetItem,QHeaderView,QMessageBox


#####
import requests as r
import pandas as pd
from datetime import date
from bs4 import BeautifulSoup
#####



class MainWindow(QMainWindow, Ui_MainWindow):
     
    def __init__(self, parent=None):
        super(MainWindow, self).__init__(parent)
        self.setupUi(self)
        self.data = []
        self.isParse = False
        self.setWindowTitle("本益比法");
        self.tabledata.horizontalHeader().setStretchLastSection(True)
        self.tabledata.horizontalHeader().setSectionResizeMode(QHeaderView.Stretch)

    
    def parseData(self,num):
        target_url = 'https://goodinfo.tw/StockInfo/StockBzPerformance.asp?STOCK_ID=' + str(num) + '&YEAR_PERIOD=9999&RPT_CAT=M_YEAR&STEP=DATA&SHEET=PER%2FPBR'
        headers  = {
            'accept': '*/*',
            'accept-encoding': 'gzip, deflate, br',
            'accept-language': 'en-US,en;q=0.9,zh;q=0.8,zh-TW;q=0.7',
            'referer': 'https://goodinfo.tw/StockInfo/StockBzPerformance.asp?STOCK_ID=2330',
            'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'
        }
        rs = r.session()
        res = rs.get(target_url, headers=headers)
        res.encoding=('utf8')
        soup = BeautifulSoup(res.text, 'html.parser')
        try:
            t = pd.read_html(res.text)
        except ValueError:    
                if soup.text == '查無資料':
                    print('此股票代號查無經營績效')
        year = list()
        high_price = list()
        low_price = list()
        avg_price = list()
        eps = list()
        for i in range(3,8):
            year.append(t[2].values[i][0])
            high_price.append(float(t[2].values[i][3]))
            low_price.append(float(t[2].values[i][4]))
            avg_price.append(float(t[2].values[i][6]))
            eps.append(float(t[2].values[i][9]))
            
        high_ROE = list()
        low_ROE = list()
        avg_ROE = list()
        
        for i in range(len(eps)):
            high_ROE.append(round(high_price[i]/eps[i], 2))
            low_ROE.append(round(low_price[i]/eps[i], 2))
            avg_ROE.append(round(avg_price[i]/eps[i], 2))
            
        high_price.append(round(sum(high_price) / float(len(high_price)), 2))
        low_price.append(round(sum(low_price) / float(len(low_price)), 2))
        avg_price.append(round(sum(avg_price) / float(len(avg_price)), 2))
        eps.append(round(sum(eps) / float(len(eps)), 2))
        high_ROE.append(round(sum(high_ROE) / float(len(high_ROE)), 2))
        low_ROE.append(round(sum(low_ROE) / float(len(low_ROE)), 2))
        avg_ROE.append(round(sum(avg_ROE) / float(len(avg_ROE)), 2))
            
        return year, high_price, low_price, avg_price, eps, high_ROE, low_ROE, avg_ROE
    
    
    def calcData(self,gEPS):
        
        cheap = (self.data[-2][-1])*float(gEPS)
        good = (self.data[-1][-1])*float(gEPS)
        exp = (self.data[-3][-1])*float(gEPS)
        safe_0 = [round(cheap, 2), round(good, 2), round(exp, 2)]
        safe_5 = [round(safe_0[0]*(1-0.05), 2), round(safe_0[1]*(1-0.05), 2), round(safe_0[2]*(1-0.05), 2)]
        safe_10 = [round(safe_0[0]*(1-0.1), 2), round(safe_0[1]*(1-0.1), 2), round(safe_0[2]*(1-0.1))]
        safe_15 = [round(safe_0[0]*(1-0.15), 2), round(safe_0[1]*(1-0.15), 2), round(safe_0[2]*(1-0.15), 2)]
        safe_20 = [round(safe_0[0]*(1-0.2), 2), round(safe_0[1]*(1-0.2), 2), round(safe_0[2]*(1-0.2), 2)]
        safe_25 = [round(safe_0[0]*(1-0.25), 2), round(safe_0[1]*(1-0.25), 2), round(safe_0[2]*(1-0.25), 2)]
        safe_30 = [round(safe_0[0]*(1-0.3), 2), round(safe_0[1]*(1-0.3), 2), round(safe_0[2]*(1-0.3), 2)]
        
        
        return safe_0, safe_5, safe_10, safe_15, safe_20, safe_25, safe_30
    @pyqtSlot()
    def on_pushButton_send_clicked(self):
        '''
        Parse Data From www.goodinfo.com
        '''
        stock_num = self.lineEdit_stock_num.text()
        if stock_num == '':
            print('You Need To Enter Stock Number')
            return self.msg('no-input')
        else:
            self.data = self.parseData(stock_num)
            self.isParse = True
            for num in range(len(self.data)):
                for i in range(len(self.data[num])):
                    item = QTableWidgetItem()
                    item.setText(str(self.data[num][i]))
                    self.tabledata.setItem(i, num, item)
    @pyqtSlot()
    def on_pushButton_calc_clicked(self):
        '''
        Calc Price
        '''
        if self.isParse:
            EPS = self.lineEdit_eps.text()
            if EPS == '':
                print('You Need To Enter EPS')
                return self.msg('no-eps')
            else:
                safe = self.calcData(EPS)
                for num in range(0, len(safe)):
                    for i in range(len(safe[num])):
                        item = QTableWidgetItem()
                        item.setText(str(safe[num][i]))
                        self.tableprice.setItem(i, num, item)
        else:
            print('You Need To Parse Data First')
            return self.msg('no-parse')
    def msg(self,status):
        if status == 'no-input':
            reply = QMessageBox.warning(self,"警告訊息","尚未輸出股票代號!")
        elif status == 'no-parse':
            reply = QMessageBox.warning(self,"警告訊息","請先查詢股票資料，再進行計算!")
        elif status == 'no-eps':
            reply = QMessageBox.warning(self,"警告訊息","請先輸入預估EPS，再進行計算!")
        return reply
        

        
if __name__ == "__main__":
    app = QApplication(sys.argv)
    window = MainWindow()
    window.show()
    sys.exit(app.exec_())

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
from PyInstaller.__main__ import run

if __name__ == '__main__':
    opts = ['-F','--paths=C:\\Users\\Kane\\AppData\\Local\\Programs\\Python\\Python37-32\\Lib\\site-packages\\PyQt5\\Qt\\bin',
            '--paths=C:\\Users\\Kane\\AppData\\Local\\Programs\\Python\\Python37-32\\Lib\\site-packages\\PyQt5\\Qt\\plugins',
            '--paths=C:\\Windows\\WinSxS\\x86_microsoft-windows-m..namespace-downlevel_31bf3856ad364e35_10.0.17134.1_none_50c6cb8431e7428f',
            '--paths=C:\\Windows\\System32',
            '--icon', 'C:\\Users\\Kane\\Documents\\Untitled Folder\\money.ico', '--noupx', '--clean',
            'stock.py']

    run(opts)
# Out:
# 2707529 INFO: PyInstaller: 3.4
# 2707530 INFO: Python: 3.7.2
# 2707531 INFO: Platform: Windows-10-10.0.17134-SP0
# 2707533 INFO: wrote C:\Users\Kane\Documents\Untitled Folder\stock.spec
# 2707536 INFO: UPX is not available.
# 2707537 INFO: Removing temporary files and cleaning cache in C:\Users\Kane\AppData\Roaming\pyinstaller
# 2707615 INFO: Extending PYTHONPATH with paths
# ['C:\\Users\\Kane\\Documents\\Untitled Folder',
#  'C:\\Users\\Kane\\AppData\\Local\\Programs\\Python\\Python37-32\\Lib\\site-packages\\PyQt5\\Qt\\bin',
#  'C:\\Users\\Kane\\AppData\\Local\\Programs\\Python\\Python37-32\\Lib\\site-packages\\PyQt5\\Qt\\plugins',
#  'C:\\Windows\\WinSxS\\x86_microsoft-windows-m..namespace-downlevel_31bf3856ad364e35_10.0.17134.1_none_50c6cb8431e7428f',
#  'C:\\Windows\\System32',
#  'C:\\Users\\Kane\\Documents\\Untitled Folder']
# 2707615 INFO: checking Analysis
# 2707615 INFO: Building Analysis because Analysis-06.toc is non existent
# 2707615 INFO: Initializing module dependency graph...
# 2707661 INFO: Initializing module graph hooks...
# 2707665 INFO: Analyzing base_library.zip ...
# 2713277 INFO: running Analysis Analysis-06.toc
# 2713277 INFO: Adding Microsoft.Windows.Common-Controls to dependent assemblies of final executable
#   required by c:\users\kane\appdata\local\programs\python\python37-32\python.exe
# 2714496 WARNING: lib not found: api-ms-win-core-file-l2-1-0.dll dependency of C:\Windows\WinSxS\x86_microsoft-windows-m..namespace-downlevel_31bf3856ad364e35_10.0.17134.1_none_50c6cb8431e7428f\ucrtbase.dll
# 2714793 INFO: Caching module hooks...
# 2714809 INFO: Analyzing C:\Users\Kane\Documents\Untitled Folder\stock.py
# 2715417 INFO: Processing pre-safe import module hook   urllib3.packages.six.moves
# 2718043 INFO: Processing pre-find module path hook   distutils
# 2718887 INFO: Processing pre-safe import module hook   six.moves
# 2722643 INFO: Processing pre-safe import module hook   setuptools.extern.six.moves
# 2723362 INFO: Processing pre-find module path hook   site
# 2723362 INFO: site: retargeting to fake-dir 'c:\\users\\kane\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages\\PyInstaller\\fake-modules'
# 2754514 INFO: Loading module hooks...
# 2754514 INFO: Loading module hook "hook-certifi.py"...
# 2754514 INFO: Loading module hook "hook-distutils.py"...
# 2754522 INFO: Loading module hook "hook-encodings.py"...
# 2754658 INFO: Loading module hook "hook-IPython.py"...
# 2754683 INFO: Excluding import 'gtk'
# 2754691 INFO: Excluding import 'tkinter'
# 2754697 INFO:   Removing import of tkinter from module IPython.lib.clipboard
# 2754700 INFO: Excluding import 'matplotlib'
# 2754707 INFO:   Removing import of matplotlib from module IPython.core.pylabtools
# 2754710 INFO: Excluding import 'PyQt5'
# 2754717 INFO:   Removing import of PyQt5 from module IPython.external.qt_loaders
# 2754718 INFO:   Removing import of PyQt5.QtCore from module IPython.external.qt_loaders
# 2754719 INFO:   Removing import of PyQt5.QtGui from module IPython.external.qt_loaders
# 2754719 INFO:   Removing import of PyQt5.QtWidgets from module IPython.external.qt_loaders
# 2754720 INFO:   Removing import of PyQt5.QtSvg from module IPython.external.qt_loaders
# 2754721 INFO: Excluding import 'PyQt4'
# 2754729 INFO:   Removing import of PyQt4 from module IPython.external.qt_loaders
# 2754731 INFO: Excluding import 'PySide'
# 2754739 INFO:   Removing import of PySide from module IPython.external.qt_loaders
# 2754741 INFO: Loading module hook "hook-jedi.py"...
# 2754753 INFO: Loading module hook "hook-jinja2.py"...
# 2754779 INFO: Loading module hook "hook-jsonschema.py"...
# 2754784 INFO: Loading module hook "hook-lib2to3.py"...
# 2754791 INFO: Loading module hook "hook-lxml.etree.py"...
# 2754793 INFO: Loading module hook "hook-numpy.core.py"...
# 2754794 INFO: Loading module hook "hook-numpy.py"...
# 2754796 INFO: Loading module hook "hook-pandas.py"...
# 2755575 INFO: Loading module hook "hook-pkg_resources.py"...
# 2756459 INFO: Processing pre-safe import module hook   win32com
# 2756801 INFO: Loading module hook "hook-pydoc.py"...
# 2756801 INFO: Loading module hook "hook-pygments.py"...
# 2759106 INFO: Loading module hook "hook-PyQt5.py"...
# 2759196 INFO: Loading module hook "hook-PyQt5.QtCore.py"...
# 2759356 INFO: Loading module hook "hook-PyQt5.QtGui.py"...
# 2759683 INFO: Loading module hook "hook-PyQt5.QtSvg.py"...
# 2760184 INFO: Loading module hook "hook-PyQt5.QtWidgets.py"...
# 2760574 INFO: Loading module hook "hook-pythoncom.py"...
# 2760990 INFO: Loading module hook "hook-pytz.py"...
# 2761126 INFO: Loading module hook "hook-pywintypes.py"...
# 2761548 INFO: Loading module hook "hook-setuptools.py"...
# 2762374 INFO: Loading module hook "hook-sqlite3.py"...
# 2762508 INFO: Loading module hook "hook-sysconfig.py"...
# 2762508 INFO: Loading module hook "hook-win32com.py"...
# 2763441 INFO: Loading module hook "hook-xml.dom.domreg.py"...
# 2763441 INFO: Loading module hook "hook-xml.etree.cElementTree.py"...
# 2763441 INFO: Loading module hook "hook-xml.py"...
# 2763452 INFO: Loading module hook "hook-zmq.py"...
# 2763997 INFO: Loading module hook "hook-_tkinter.py"...
# 2764219 INFO: checking Tree
# 2764219 INFO: Building Tree because Tree-10.toc is non existent
# 2764219 INFO: Building Tree Tree-10.toc
# 2764345 INFO: checking Tree
# 2764345 INFO: Building Tree because Tree-11.toc is non existent
# 2764345 INFO: Building Tree Tree-11.toc
# 2764637 INFO: Looking for ctypes DLLs
# 2764760 INFO: Analyzing run-time hooks ...
# 2764775 INFO: Including run-time hook 'pyi_rth_qt5.py'
# 2764775 INFO: Including run-time hook 'pyi_rth_multiprocessing.py'
# 2764795 INFO: Including run-time hook 'pyi_rth_pkgres.py'
# 2764802 INFO: Including run-time hook 'pyi_rth_win32comgenpy.py'
# 2764805 INFO: Including run-time hook 'pyi_rth__tkinter.py'
# 2764809 INFO: Including run-time hook 'pyi_rth_traitlets.py'
# 2764860 INFO: Looking for dynamic libraries
# 2766676 WARNING: lib not found: libzmq.cp37-win32.pyd dependency of c:\users\kane\appdata\local\programs\python\python37-32\lib\site-packages\zmq\backend\cython\error.cp37-win32.pyd
# 2766941 WARNING: lib not found: libzmq.cp37-win32.pyd dependency of c:\users\kane\appdata\local\programs\python\python37-32\lib\site-packages\zmq\backend\cython\socket.cp37-win32.pyd
# 2767207 WARNING: lib not found: libzmq.cp37-win32.pyd dependency of c:\users\kane\appdata\local\programs\python\python37-32\lib\site-packages\zmq\backend\cython\utils.cp37-win32.pyd
# 2767480 WARNING: lib not found: libzmq.cp37-win32.pyd dependency of c:\users\kane\appdata\local\programs\python\python37-32\lib\site-packages\zmq\backend\cython\message.cp37-win32.pyd
# 2767746 WARNING: lib not found: libzmq.cp37-win32.pyd dependency of c:\users\kane\appdata\local\programs\python\python37-32\lib\site-packages\zmq\backend\cython\context.cp37-win32.pyd
# 2768004 WARNING: lib not found: libzmq.cp37-win32.pyd dependency of c:\users\kane\appdata\local\programs\python\python37-32\lib\site-packages\zmq\backend\cython\_version.cp37-win32.pyd
# 2768264 WARNING: lib not found: libzmq.cp37-win32.pyd dependency of c:\users\kane\appdata\local\programs\python\python37-32\lib\site-packages\zmq\backend\cython\_poll.cp37-win32.pyd
# 2768522 WARNING: lib not found: libzmq.cp37-win32.pyd dependency of c:\users\kane\appdata\local\programs\python\python37-32\lib\site-packages\zmq\backend\cython\_device.cp37-win32.pyd
# 2784715 INFO: Looking for eggs
# 2784715 INFO: Using Python library c:\users\kane\appdata\local\programs\python\python37-32\python37.dll
# 2784715 INFO: Found binding redirects:
# []
# 2784765 INFO: Warnings written to C:\Users\Kane\Documents\Untitled Folder\build\stock\warn-stock.txt
# 2785374 INFO: Graph cross-reference written to C:\Users\Kane\Documents\Untitled Folder\build\stock\xref-stock.html
# 2785598 INFO: checking PYZ
# 2785598 INFO: Building PYZ because PYZ-04.toc is non existent
# 2785598 INFO: Building PYZ (ZlibArchive) C:\Users\Kane\Documents\Untitled Folder\build\stock\PYZ-04.pyz
# 2800618 INFO: Building PYZ (ZlibArchive) C:\Users\Kane\Documents\Untitled Folder\build\stock\PYZ-04.pyz completed successfully.
# 2800732 INFO: checking PKG
# 2800732 INFO: Building PKG because PKG-04.toc is non existent
# 2800732 INFO: Building PKG (CArchive) PKG-04.pkg
# 2802219 WARNING: One binary added with two internal names.
# 2802220 WARNING: ('libGLESv2.dll',
#  'C:\\users\\kane\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages\\PyQt5\\Qt\\bin\\libGLESv2.dll',
#  'BINARY')
# 2802220 WARNING: was placed previously at
# 2802221 WARNING: ('PyQt5\\Qt\\bin\\libGLESv2.dll',
#  'C:\\users\\kane\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages\\PyQt5\\Qt\\bin\\libGLESv2.dll',
#  'BINARY')
# 2821589 INFO: Building PKG (CArchive) PKG-04.pkg completed successfully.
# 2821697 INFO: Bootloader c:\users\kane\appdata\local\programs\python\python37-32\lib\site-packages\PyInstaller\bootloader\Windows-32bit\run.exe
# 2821697 INFO: checking EXE
# 2821697 INFO: Building EXE because EXE-04.toc is non existent
# 2821697 INFO: Building EXE from EXE-04.toc
# 2821709 INFO: SRCPATH [('C:\\Users\\Kane\\Documents\\Untitled Folder\\money.ico', None)]
# 2821710 INFO: Updating icons from ['C:\\Users\\Kane\\Documents\\Untitled Folder\\money.ico'] to C:\Users\Kane\AppData\Local\Temp\tmpce449251
# 2821711 INFO: Writing RT_GROUP_ICON 0 resource with 20 bytes
# 2821712 INFO: Writing RT_ICON 1 resource with 67624 bytes
# 2821720 INFO: Appending archive to EXE C:\Users\Kane\Documents\Untitled Folder\dist\stock.exe
# 2821813 INFO: Building EXE from EXE-04.toc completed successfully.
